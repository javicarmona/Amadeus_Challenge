# %%
import pandas as pd

# %% [markdown]
# ## Exercise 4
# ### Match searches with bookings
#
#
# For every search in the searches file, find out whether the search ended up in a booking or not (using the info in the bookings file). For instance, search and booking origin and destination should match.
#
# For the bookings file, origin and destination are the columns dep_port and arr_port, respectively.
#
# Generate a CSV file with the search data, and an additional field, containing 1 if the search ended up in a booking, and 0 otherwise.

# %%
df_search = pd.read_csv('searches.csv', delimiter='^', nrows=10000) # limite para pruebas nrows=1000000
df_book = pd.read_csv('bookings.csv', delimiter='^', nrows=10000) # limite para pruebas nrows=1000000

# %%
dfsum = df_search.merge(df_book, left_on=['dep_port','arr_port'] , right_on=['Origin','Destination'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-262-44207d4df0ca> in <module>
# ----> 1 dfsum = df_search.merge(df_book, left_on=['dep_port','arr_port'] , right_on=['Origin','Destination'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7321             copy=copy,
#    7322             indicator=indicator,
# -> 7323             validate=validate,
#    7324         )
#    7325
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      80         copy=copy,
#      81         indicator=indicator,
# ---> 82         validate=validate,
#      83     )
#      84     return op.get_result()
#
# ...

# %%
df_book['arr_port']
# Out:
# 0       LHR
# 1       CLT
# 2       CLT
# 3       SVO
# 4       SVO
#           ...
# 9995    HAN
# 9996    HAN
# 9997    SGN
# 9998    SGN
# 9999    SGN
# Name: arr_port, Length: 10000, dtype: object

# %%
df_search.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure  ... Seg6Arrival  \
# 0    TXL         AUH          1           2           TXL  ...         NaN
# 1    ATH         MIL          0           1           ATH  ...         NaN
# 2    ICT         SFO          1           2           ICT  ...         NaN
# 3    RNB         ARN          0           1           RNB  ...         NaN
# 4    OSL         MAD          1           2           OSL  ...         NaN
#
#   Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
result = pd.merge(df_book, df_search, left_on=['dep_port','arr_port'] , right_on=['Origin','Destination'])

# %%
df_search.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure  ... Seg6Arrival  \
# 0    TXL         AUH          1           2           TXL  ...         NaN
# 1    ATH         MIL          0           1           ATH  ...         NaN
# 2    ICT         SFO          1           2           ICT  ...         NaN
# 3    RNB         ARN          0           1           RNB  ...         NaN
# 4    OSL         MAD          1           2           OSL  ...         NaN
#
#   Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
df_book.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port  ...  route            \
# ...

# %%
df_book.keys()
# Out:
# Index(['Date', 'Time', 'TxnCode', 'OfficeID', 'Country', 'Origin',
#        'Destination', 'RoundTrip', 'NbSegments', 'Seg1Departure',
#        'Seg1Arrival', 'Seg1Date', 'Seg1Carrier', 'Seg1BookingCode',
#        'Seg2Departure', 'Seg2Arrival', 'Seg2Date', 'Seg2Carrier',
#        'Seg2BookingCode', 'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
#        'Seg3Carrier', 'Seg3BookingCode', 'Seg4Departure', 'Seg4Arrival',
#        'Seg4Date', 'Seg4Carrier', 'Seg4BookingCode', 'Seg5Departure',
#        'Seg5Arrival', 'Seg5Date', 'Seg5Carrier', 'Seg5BookingCode',
#        'Seg6Departure', 'Seg6Arrival', 'Seg6Date', 'Seg6Carrier',
#        'Seg6BookingCode', 'From', 'IsPublishedForNeg', 'IsFromInternet',
#        'IsFromVista', 'TerminalID', 'InternetOffice'],
#       dtype='object')

# %%
df_book.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure  ... Seg6Arrival  \
# 0    TXL         AUH          1           2           TXL  ...         NaN
# 1    ATH         MIL          0           1           ATH  ...         NaN
# 2    ICT         SFO          1           2           ICT  ...         NaN
# 3    RNB         ARN          0           1           RNB  ...         NaN
# 4    OSL         MAD          1           2           OSL  ...         NaN
#
#   Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
len(dfsum)
# Out:
# 10000

# %%
dfsum[1:1000]
# Out:
#          Date_x    Time_x TxnCode_x                        OfficeID_x  \
# 1    2013-01-01  10:15:33       MPT  b0af35b31588dc4ab06d5cf2986e8e02
# 2    2013-01-01  18:04:49       MPT  3561a60621de06ab1badc8ca55699ef3
# 3    2013-01-01  17:42:40       FXP  1864e5e8013d9414150e91d26b6a558b
# 4    2013-01-01  17:48:29       MPT  1ec336348f44207d2e0027dc3a68c118
# 5    2013-01-01  22:00:28       MPT  3561a60621de06ab1badc8ca55699ef3
# ..          ...       ...       ...                               ...
# 995  2013-01-02  10:11:07       MPT  624d8c3ac0b3a7ca03e3c167e0f48327
# 996  2013-01-02  10:11:07       MPT  624d8c3ac0b3a7ca03e3c167e0f48327
# 997  2013-01-02  10:11:07       MPT  624d8c3ac0b3a7ca03e3c167e0f48327
# 998  2013-01-02  10:11:07       MPT  624d8c3ac0b3a7ca03e3c167e0f48327
# 999  2013-01-02  10:11:07       MPT  624d8c3ac0b3a7ca03e3c167e0f48327
#
#     Country_x Origin Destination  RoundTrip_x  NbSegments_x Seg1Departure_x  \
# ...

# %%
len(dfsum)
# Out:
# 20556

# %%
len(df_search)
# Out:
# 10000

# %%
len(df_book)
# Out:
# 10000

# %%
import numpy as np

nona = dfsum['Seg6BookingCode_y'][-dfsum.isna()]

nona
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-193-400c527f61f6> in <module>
#       1 import numpy as np
#       2
# ----> 3 nona = dfsum['Seg6BookingCode_y'][-dfsum.isna()]
#       4
#       5 nona
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1104             key = check_bool_indexer(self.index, key)
#    1105
# -> 1106         return self._get_with(key)
#    1107
#    1108     def _get_with(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _get_with(self, key)
#    1113         elif isinstance(key, ABCDataFrame):
#    1114             raise TypeError(
# -> 1115                 "Indexing a Series with DataFrame is not "
#    1116                 "supported, use the appropriate DataFrame column"
#    1117             )
#
# ...

# %%
df_book['Seg6BookingCode']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 9995    NaN
# 9996    NaN
# 9997    NaN
# 9998    NaN
# 9999    NaN
# Name: Seg6BookingCode, Length: 10000, dtype: object

# %%
len(dfsum)
# Out:
# 20556

# %%
df_book.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure  ... Seg6Arrival  \
# 0    TXL         AUH          1           2           TXL  ...         NaN
# 1    ATH         MIL          0           1           ATH  ...         NaN
# 2    ICT         SFO          1           2           ICT  ...         NaN
# 3    RNB         ARN          0           1           RNB  ...         NaN
# 4    OSL         MAD          1           2           OSL  ...         NaN
#
#   Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
dfsum['From_y'] != str
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20551    False
# 20552    False
# 20553    False
# 20554    False
# 20555    False
# Name: From_y, Length: 20556, dtype: bool

# %%
len(a)
# Out:
# 20556

# %%
a
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 20551    True
# 20552    True
# 20553    True
# 20554    True
# 20555    True
# Name: From_y, Length: 20556, dtype: bool

# %%
df1 = pd.DataFrame({'data1': range(5,8), 'key': list('bac'), 'key2': list('bac')})
df2 = pd.DataFrame({'data2': range(56,59), 'key': list('abd')})

# %%
df1 = pd.DataFrame({'data1': range(5,12), 'key': list('bbacaab'), 'key2': list('bbacaab')})
df2 = pd.DataFrame({'data2': range(56,59), 'key': list('abd'), 'key2': list('abd')})

# %%
dfsum = df1.merge(df2, left_on=['key','key2'] , right_on=['key','key2']

# %%
df3 = df1.merge(df2)

# %%
df3
# Out:
#    data1 key  data2
# 0      5   b     57
# 1      6   a     56

# %%
df1
# Out:
#    data1 key key2
# 0      5   b    b
# 1      6   b    b
# 2      7   a    a
# 3      8   c    c
# 4      9   a    a
# 5     10   a    a
# 6     11   b    b

# %%
df2
# Out:
#    data2 key key2
# 0     56   a    a
# 1     57   b    b
# 2     58   d    d

# %%
dfsum = df1.merge(df2, left_on=['key','key2'] , right_on=['key','key2'])

# %%
dfsum
# Out:
#    data1 key key2  data2
# 0      5   b    b     57
# 1      6   b    b     57
# 2     11   b    b     57
# 3      7   a    a     56
# 4      9   a    a     56
# 5     10   a    a     56

# %%
df9 = dfsum.drop_duplicates(['OfficeID_x'])

# %%
len(df9)
# Out:
# 1321

# %%
len(dfsum)
# Out:
# 20556

# %%
dfsum.head()
# Out:
#        Date_x    Time_x TxnCode_x                        OfficeID_x Country_x  \
# 0  2013-01-01  20:25:57       MPT  624d8c3ac0b3a7ca03e3c167e0f48327        DE
# 1  2013-01-01  10:15:33       MPT  b0af35b31588dc4ab06d5cf2986e8e02        MD
# 2  2013-01-01  18:04:49       MPT  3561a60621de06ab1badc8ca55699ef3        US
# 3  2013-01-01  17:42:40       FXP  1864e5e8013d9414150e91d26b6a558b        SE
# 4  2013-01-01  17:48:29       MPT  1ec336348f44207d2e0027dc3a68c118        NO
#
#   Origin Destination  RoundTrip_x  NbSegments_x Seg1Departure_x  ...  \
# 0    TXL         AUH            1             2             TXL  ...
# 1    ATH         MIL            0             1             ATH  ...
# 2    ICT         SFO            1             2             ICT  ...
# 3    RNB         ARN            0             1             RNB  ...
# 4    OSL         MAD            1             2             OSL  ...
#
#   Seg6Arrival_y Seg6Date_y Seg6Carrier_y Seg6BookingCode_y  From_y  \
# ...

# %%
dfsum['OfficeID_x']
# Out:
# 0        624d8c3ac0b3a7ca03e3c167e0f48327
# 1        b0af35b31588dc4ab06d5cf2986e8e02
# 2        3561a60621de06ab1badc8ca55699ef3
# 3        1864e5e8013d9414150e91d26b6a558b
# 4        1ec336348f44207d2e0027dc3a68c118
#                        ...
# 20551    69cede70ffea2435621303e7e3114eb2
# 20552    e0ca92b506fbf482891d34ccebad0f32
# 20553    6abcf3118f899e9f6fd7abe9e1167304
# 20554    5a59deba021eacb7a54d813ddcb4ce2a
# 20555    b695299cc14ddcd1e31f1c922b3e258c
# Name: OfficeID_x, Length: 20556, dtype: object

# %%
df9 = dfsum.drop_duplicates(['Seg6BookingCode'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-250-bf39070b56f1> in <module>
# ----> 1 df9 = dfsum.drop_duplicates(['Seg6BookingCode'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    4887
#    4888         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4889         duplicated = self.duplicated(subset, keep=keep)
#    4890
#    4891         if inplace:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4944         diff = Index(subset).difference(self.columns)
#    4945         if not diff.empty:
# -> 4946             raise KeyError(diff)
#    4947
#    4948         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['Seg6BookingCode'], dtype='object')

# %%
len(df_search)
# Out:
# 10000

# %%
dfff = df_search.drop_duplicates(['TerminalID'])

# %%
df_book.keys()
# Out:
# Index(['Date', 'Time', 'TxnCode', 'OfficeID', 'Country', 'Origin',
#        'Destination', 'RoundTrip', 'NbSegments', 'Seg1Departure',
#        'Seg1Arrival', 'Seg1Date', 'Seg1Carrier', 'Seg1BookingCode',
#        'Seg2Departure', 'Seg2Arrival', 'Seg2Date', 'Seg2Carrier',
#        'Seg2BookingCode', 'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
#        'Seg3Carrier', 'Seg3BookingCode', 'Seg4Departure', 'Seg4Arrival',
#        'Seg4Date', 'Seg4Carrier', 'Seg4BookingCode', 'Seg5Departure',
#        'Seg5Arrival', 'Seg5Date', 'Seg5Carrier', 'Seg5BookingCode',
#        'Seg6Departure', 'Seg6Arrival', 'Seg6Date', 'Seg6Carrier',
#        'Seg6BookingCode', 'From', 'IsPublishedForNeg', 'IsFromInternet',
#        'IsFromVista', 'TerminalID', 'InternetOffice'],
#       dtype='object')

# %%
len(dfff)
# Out:
# 864

# %%
df_book.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure  ... Seg6Arrival  \
# 0    TXL         AUH          1           2           TXL  ...         NaN
# 1    ATH         MIL          0           1           ATH  ...         NaN
# 2    ICT         SFO          1           2           ICT  ...         NaN
# 3    RNB         ARN          0           1           RNB  ...         NaN
# 4    OSL         MAD          1           2           OSL  ...         NaN
#
#   Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...
